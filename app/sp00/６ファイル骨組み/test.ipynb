# %%
#実行環境のテスト用
print("check")
# Out:
# check
# Looking in indexes: https://pypi.org/simple, https://www.piwheels.org/simple
# ...
#   Obtaining dependency information for nest_asyncio from https://www.piwheels.org/simple/nest-asyncio/nest_asyncio-1.6.0-py3-none-any.whl.metadata
# ...
# Using cached https://www.piwheels.org/simple/nest-asyncio/nest_asyncio-1.6.0-py3-none-any.whl (5.2 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.
