# %%
from pathlib import Path

# 現在Jupyterが認識しているフォルダを確認
print("現在の作業ディレクトリ:", Path.cwd().absolute())

# url.txt が本当に存在するか確認
url_file = Path("url.txt")
print("url.txt のパス:", url_file.absolute())
print("ファイルは存在しますか？ →", url_file.exists())
# Out:
# 現在の作業ディレクトリ: /home/bdjp/Desktop/vs01
# url.txt のパス: /home/bdjp/Desktop/vs01/url.txt
# ファイルは存在しますか？ → False
